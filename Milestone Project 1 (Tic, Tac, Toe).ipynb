# %%
from IPython.display import clear_output
clear_output()


print ('Welcome to the Tic Tac Toe project, by Valentino Masala.')
print ('This is my first project in Python')
print ("But let's just start the game!")

player1 = input('What is the name of Player 1? ').capitalize()
print (f'Thank you {player1}, next!')

player2 = input('What is the name of Player 2? ').capitalize()
print (f'Thank you {player2}!')

player1_choice = []
player2_choice = []



def choice_player1():
    scelta = False 
    
    while scelta == False:
        
        x_o = input(f'{player1}, do you want to play with X or O? ').lower()
        if x_o == 'x':
            player1_choice.append(x_o)
            player2_choice = 'O'
            print (f"Perfect, you chose {x_o.upper()}. {player2} is {player2_choice}. Let's play!")
            scelta = True
        elif x_o == 'o':
            player1_choice.append(x_o)
            player2_choice = 'X'
            print (f"Perfect, you chose {x_o.upper()}. {player2} is {player2_choice}. Let's play!")
            scelta = True
            
        else:
            print(f"\n{player1}, that wasn't 'X' or 'O'. Chose again" )





def scelta():
    print ('           |       |   ')
    print ('        7  |   8   | 9 ')
    print ('           |       |   ')
    print ('      -----------------')
    print ('           |       |   ')
    print ('        4  |   5   | 6 ')
    print ('           |       |   ')
    print ('      -----------------')
    print ('           |       |   ')
    print ('        1  |   2   |  3 ')
    print ('           |       |   ') 
    input ('      Use the number pad\n             Ok? ')
    
    
    vittoria = False
    
    linea1= [7,8,9] 
    linea2= [4,5,6]
    linea3= [1,2,3]   
    
    
    
    def display_game(x):
        print ('           |       |    ')
        print (f'        {linea1[0]}  |   {linea1[1]}   |  {linea1[2]}')
        print ('           |       |    ')
        print ('      -------------------')
        print ('           |       |    ')
        print (f'        {linea2[0]}  |   {linea2[1]}   |  {linea2[2]}')
        print ('           |       |    ')
        print ('      -------------------')
        print ('           |       |    ')
        print (f'        {linea3[0]}  |   {linea3[1]}   |  {linea3[2]}')
        print ('           |       |    ')
        
        
            
    def winning_case():
        if linea1[0] == linea1[1] == linea1[2]:
            if linea1[0] == 'X':
                print('X won the game!')
                return True
            elif linea1[0] == 'O':
                print('O won the game!')
                return True
        elif linea2[0] == linea2[1] == linea2[2]:
            if linea2[0] == 'X':
                print('X won the game!')
                return True
            elif linea2[0] == 'O':
                print('O won the game!')
                return True

        elif linea3[0] == linea3[1] == linea3[2]:
            if linea3[0] == 'X':
                print('X won the game!')
                return True
            elif linea3[0] == 'O':
                print('O won the game!')
                return True

        elif linea1[0] == linea2[0] == linea3[0]:
            if linea2[0] == 'X':
                print('X won the game!')
                return True
            elif linea2[0] == 'O':
                print('O won the game!')
                return True

        elif linea1[1] == linea2[1] == linea3[1]:
            if linea2[1] == 'X':
                print('X won the game!')
                return True
            elif linea2[1] == 'O':
                print('O won the game!')
                return True

        elif linea1[2] == linea2[2] == linea3[2]:
            if linea2[2] == 'X':
                print('X won the game!')
                return True
            elif linea2[2] == 'O':
                print('O won the game!')
                return True

        elif linea1[0] == linea2[1] == linea3[2]:
            if linea2[1] == 'X':
                print('X won the game!')
                return True
            elif linea2[1] == 'O':
                print('O won the game!')
                return True

        elif linea1[2] == linea2[1] == linea3[0]:
            if linea2[1] == 'X':
                print('X won the game!')
                return True
            elif linea2[1] == 'O':
                print('O won the game!')
                return True
        
        
        
        
        
    
        
    while vittoria == False:
        
        if winning_case() == True:
            break
        else:
            pass
        
        x = int(input('Chose a position '))
        clear_output()
        if x == 7:
            linea1[0] = 'X'
            display_game(x)
        elif x == 8:
            linea1[1] = 'X'
            display_game(x)
        elif x == 9:
            linea1[2] = 'X'
            display_game(x)
        elif x == 4:
            linea2[0] = 'X'
            display_game(x)
        elif x == 5:
            linea2[1] = 'X'
            display_game(x)
        elif x == 6:
            linea2[2] = 'X'
            display_game(x)
        elif x == 1:
            linea3[0] = 'X'
            display_game(x)
        elif x == 2:
            linea3[1] = 'X'
            display_game(x)
        elif x == 3:
            linea3[2] = 'X'
            display_game(x)
        else:
            print("That position do not exist")
            continue      
    
        if winning_case() == True:
            break
        else:
            pass
        
        o = int(input('Chose a position '))
        clear_output()
        if o == 7:
            linea1[0] = 'O'
            display_game(o)
        elif o == 8: 
            linea1[1] = 'O'
            display_game(o)
        elif o == 9:
            linea1[2] = 'O'
            display_game(o)
        elif o == 4:
            linea2[0] = 'O'
            display_game(o)
        elif o == 5:
            linea2[1] = 'O'
            display_game(o)
        elif o == 6:
            linea2[2] = 'O'
            display_game(o)
        elif o == 1:
            linea3[0] = 'O'
            display_game(o)
        elif o == 2:
            linea3[1] = 'O'
            display_game(o)
        elif o == 3:
            linea3[2] = 'O'
            display_game(o)
        elif o > 9:
            print("That position do not exist")
            continue
                
    
    vittoria = True
    if vittoria == True:
        giocare = input('Do you want to play again? ').lower()
        if giocare == 'yes':
            clear_output()
            scelta()
        elif giocare == 'no':
            clear_output()
            print('Hope to see you again!')
            pass
        else:
            print ("That wasn't a valid answer")
            
            
choice_player1()
scelta()
